# %%
record={"101": {"Name": "Chocolate pudding", "price": 100, "quantity": 30,"discount": 5 , "Category":"Food"}, 
 "102": {"Name": "Chocolate Cake", "pr": 800, "quantity": 100,"discount": 12 , "Category":"Food"}, 
 "103": {"Name": "Drinks", "price": 85, "quantity": 100 , "discount":10 , "Category":"Food"}, 
 "104": {"Name": "Candy", "price": 5, "quantity": 500 , "discount":2 , "Category":"Food"}, 
 "105": {"Name": "Butter", "price": 20, "quantity": 50 , "discount":5 , "Category":"Food"}, 
 "106": {"Name": "Biscuit", "price": 50, "quantity": 100 , "discount":5 , "Category":"Food"},
 "107": {"Name": "Cookies", "price": 15, "quantity": 0 , "discount":5 , "Category":"Food"},
 "108": {"Name": "Milk", "price": 30, "quantity": 20 , "discount":2 , "Category":"Food"},
 "109": {"Name": "Headphones", "price": 1999, "quantity": 10 , "discount":10 , "Category":"Hardware"},
 "110": {"Name": "Speaker", "price": 999, "quantity": 10 , "discount":10 , "Category":"Hardware"},     
 "111": {"Name": "Stabilizer", "price": 599, "quantity": 15 , "discount":10 , "Category":"Hardware"},
 "112": {"Name": "Mixer", "price": 799, "quantity": 10 , "discount":15 , "Category":"Hardware"},
 "113": {"Name": "Charger", "price": 199, "quantity": 45 , "discount":10 , "Category":"Hardware"},
 "114": {"Name": "DVD", "price": 1900, "quantity": 10 , "discount":20 , "Category":"Hardware"},
 "115": {"Name": "Camera", "price": 999, "quantity": 50 , "discount":0 , "Category":"Hardware"},
 "116": {"Name": "Chips", "price": 10, "quantity": 30,"discount": 0 , "Category":"Food"}, 
 "117": {"Name": "Milk Cake", "pr": 80, "quantity": 100,"discount": 5 , "Category":"Food"}, 
 "118": {"Name": "Diet coke", "price": 85, "quantity": 100 , "discount":10 , "Category":"Food"}, 
 "119": {"Name": "Remote", "price": 199, "quantity": 10 , "discount":5 , "Category":"Hardware"},
 "120": {"Name": "Coke", "price": 50, "quantity": 500 , "discount":5 , "Category":"Food"}, 
 "121": {"Name": "Noodles", "price": 20, "quantity": 50 , "discount":0 , "Category":"Food"}, 
 "122": {"Name": "Ketchep", "price": 50, "quantity": 100 , "discount":5 , "Category":"Food"},
 "123": {"Name": "Batter", "price": 35, "quantity": 40 , "discount":0 , "Category":"Food"},
 "124": {"Name": "Paneer", "price": 30, "quantity": 20 , "discount":0 , "Category":"Food"},
 "125": {"Name": "iphone5", "price": 50000, "quantity": 5 , "discount":10 , "Category":"Hardware"},
 "126": {"Name": "Connector", "price": 299, "quantity": 10 , "discount":5 , "Category":"Hardware"},
 "127": {"Name": "Pendrive", "price": 199, "quantity": 18 , "discount":5 , "Category":"Hardware"},
 "128": {"Name": "Flashlight", "price": 400, "quantity": 40 , "discount":10 , "Category":"Hardware"},
 "129": {"Name": "Harddrive", "price": 599, "quantity": 10 , "discount":10 , "Category":"Hardware"},
 "130": {"Name": "Modem", "price": 699, "quantity": 10 , "discount":5 , "Category":"Hardware"}}

# %%
record
# Out:
# {'101': {'Name': 'Chocolate pudding',
#   'price': 100,
#   'quantity': 30,
#   'discount': 5,
#   'Category': 'Food'},
#  '102': {'Name': 'Chocolate Cake',
#   'pr': 800,
#   'quantity': 100,
#   'discount': 12,
#   'Category': 'Food'},
#  '103': {'Name': 'Drinks',
#   'price': 85,
#   'quantity': 100,
#   'discount': 10,
#   'Category': 'Food'},
#  '104': {'Name': 'Candy',
#   'price': 5,
#   'quantity': 500,
#   'discount': 2,
#   'Category': 'Food'},
#  '105': {'Name': 'Butter',
#   'price': 20,
#   'quantity': 50,
#   'discount': 5,
#   'Category': 'Food'},
#  '106': {'Name': 'Biscuit',
#   'price': 50,
#   'quantity': 100,
#   'discount': 5,
#   'Category': 'Food'},
#  '107': {'Name': 'Cookies',
#   'price': 15,
#   'quantity': 0,
#   'discount': 5,
#   'Category': 'Food'},
#  '108': {'Name': 'Milk',
#   'price': 30,
#   'quantity': 20,
#   'discount': 2,
#   'Category': 'Food'},
#  '109': {'Name': 'Headphones',
#   'price': 1999,
#   'quantity': 10,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '110': {'Name': 'Speaker',
#   'price': 999,
#   'quantity': 10,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '111': {'Name': 'Stabilizer',
#   'price': 599,
#   'quantity': 15,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '112': {'Name': 'Mixer',
#   'price': 799,
#   'quantity': 10,
#   'discount': 15,
#   'Category': 'Hardware'},
#  '113': {'Name': 'Charger',
#   'price': 199,
#   'quantity': 45,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '114': {'Name': 'DVD',
#   'price': 1900,
#   'quantity': 10,
#   'discount': 20,
#   'Category': 'Hardware'},
#  '115': {'Name': 'Camera',
#   'price': 999,
#   'quantity': 50,
#   'discount': 0,
#   'Category': 'Hardware'},
#  '116': {'Name': 'Chips',
#   'price': 10,
#   'quantity': 30,
#   'discount': 0,
#   'Category': 'Food'},
#  '117': {'Name': 'Milk Cake',
#   'pr': 80,
#   'quantity': 100,
#   'discount': 5,
#   'Category': 'Food'},
#  '118': {'Name': 'Diet coke',
#   'price': 85,
#   'quantity': 100,
#   'discount': 10,
#   'Category': 'Food'},
#  '119': {'Name': 'Remote',
#   'price': 199,
#   'quantity': 10,
#   'discount': 5,
#   'Category': 'Hardware'},
#  '120': {'Name': 'Coke',
#   'price': 50,
#   'quantity': 500,
#   'discount': 5,
#   'Category': 'Food'},
#  '121': {'Name': 'Noodles',
#   'price': 20,
#   'quantity': 50,
#   'discount': 0,
#   'Category': 'Food'},
#  '122': {'Name': 'Ketchep',
#   'price': 50,
#   'quantity': 100,
#   'discount': 5,
#   'Category': 'Food'},
#  '123': {'Name': 'Batter',
#   'price': 35,
#   'quantity': 40,
#   'discount': 0,
#   'Category': 'Food'},
#  '124': {'Name': 'Paneer',
#   'price': 30,
#   'quantity': 20,
#   'discount': 0,
#   'Category': 'Food'},
#  '125': {'Name': 'iphone5',
#   'price': 50000,
#   'quantity': 5,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '126': {'Name': 'Connector',
#   'price': 299,
#   'quantity': 10,
#   'discount': 5,
#   'Category': 'Hardware'},
#  '127': {'Name': 'Pendrive',
#   'price': 199,
#   'quantity': 18,
#   'discount': 5,
#   'Category': 'Hardware'},
#  '128': {'Name': 'Flashlight',
#   'price': 400,
#   'quantity': 40,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '129': {'Name': 'Harddrive',
#   'price': 599,
#   'quantity': 10,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '130': {'Name': 'Modem',
#   'price': 699,
#   'quantity': 10,
#   'discount': 5,
#   'Category': 'Hardware'}}

# %%
import json

# %%
js=json.dumps(record)

# %%
fd = open("record.json",'w')
fd.write(js)
fd.close()

# %%
fd = open("record.json",'r')
r = fd.read()
fd.close()
records = json.loads(r)

# %%
records
# Out:
# {'101': {'Name': 'Chocolate pudding',
#   'price': 100,
#   'quantity': 30,
#   'discount': 5,
#   'Category': 'Food'},
#  '102': {'Name': 'Chocolate Cake',
#   'pr': 800,
#   'quantity': 100,
#   'discount': 12,
#   'Category': 'Food'},
#  '103': {'Name': 'Drinks',
#   'price': 85,
#   'quantity': 100,
#   'discount': 10,
#   'Category': 'Food'},
#  '104': {'Name': 'Candy',
#   'price': 5,
#   'quantity': 500,
#   'discount': 2,
#   'Category': 'Food'},
#  '105': {'Name': 'Butter',
#   'price': 20,
#   'quantity': 50,
#   'discount': 5,
#   'Category': 'Food'},
#  '106': {'Name': 'Biscuit',
#   'price': 50,
#   'quantity': 100,
#   'discount': 5,
#   'Category': 'Food'},
#  '107': {'Name': 'Cookies',
#   'price': 15,
#   'quantity': 0,
#   'discount': 5,
#   'Category': 'Food'},
#  '108': {'Name': 'Milk',
#   'price': 30,
#   'quantity': 20,
#   'discount': 2,
#   'Category': 'Food'},
#  '109': {'Name': 'Headphones',
#   'price': 1999,
#   'quantity': 10,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '110': {'Name': 'Speaker',
#   'price': 999,
#   'quantity': 10,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '111': {'Name': 'Stabilizer',
#   'price': 599,
#   'quantity': 15,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '112': {'Name': 'Mixer',
#   'price': 799,
#   'quantity': 10,
#   'discount': 15,
#   'Category': 'Hardware'},
#  '113': {'Name': 'Charger',
#   'price': 199,
#   'quantity': 45,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '114': {'Name': 'DVD',
#   'price': 1900,
#   'quantity': 10,
#   'discount': 20,
#   'Category': 'Hardware'},
#  '115': {'Name': 'Camera',
#   'price': 999,
#   'quantity': 50,
#   'discount': 0,
#   'Category': 'Hardware'},
#  '116': {'Name': 'Chips',
#   'price': 10,
#   'quantity': 30,
#   'discount': 0,
#   'Category': 'Food'},
#  '117': {'Name': 'Milk Cake',
#   'pr': 80,
#   'quantity': 100,
#   'discount': 5,
#   'Category': 'Food'},
#  '118': {'Name': 'Diet coke',
#   'price': 85,
#   'quantity': 100,
#   'discount': 10,
#   'Category': 'Food'},
#  '119': {'Name': 'Remote',
#   'price': 199,
#   'quantity': 10,
#   'discount': 5,
#   'Category': 'Hardware'},
#  '120': {'Name': 'Coke',
#   'price': 50,
#   'quantity': 500,
#   'discount': 5,
#   'Category': 'Food'},
#  '121': {'Name': 'Noodles',
#   'price': 20,
#   'quantity': 50,
#   'discount': 0,
#   'Category': 'Food'},
#  '122': {'Name': 'Ketchep',
#   'price': 50,
#   'quantity': 100,
#   'discount': 5,
#   'Category': 'Food'},
#  '123': {'Name': 'Batter',
#   'price': 35,
#   'quantity': 40,
#   'discount': 0,
#   'Category': 'Food'},
#  '124': {'Name': 'Paneer',
#   'price': 30,
#   'quantity': 20,
#   'discount': 0,
#   'Category': 'Food'},
#  '125': {'Name': 'iphone5',
#   'price': 50000,
#   'quantity': 5,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '126': {'Name': 'Connector',
#   'price': 299,
#   'quantity': 10,
#   'discount': 5,
#   'Category': 'Hardware'},
#  '127': {'Name': 'Pendrive',
#   'price': 199,
#   'quantity': 18,
#   'discount': 5,
#   'Category': 'Hardware'},
#  '128': {'Name': 'Flashlight',
#   'price': 400,
#   'quantity': 40,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '129': {'Name': 'Harddrive',
#   'price': 599,
#   'quantity': 10,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '130': {'Name': 'Modem',
#   'price': 699,
#   'quantity': 10,
#   'discount': 5,
#   'Category': 'Hardware'}}

# %%
product_id = str(input("Enter the product ID:"))
Name = str(input("Enter the product Name:"))
price = int(input("Enter the product Price:"))
quantity = int(input("Enter the quantity :"))
discount = int(input("Enter the discount:"))
Category = str(input("Enter the Category the product belongs to:"))
record[product_id] = {'Name': Name, 'price': price, 'quantity': quantity, 'discount':discount, 'Category':Category}
js = json.dumps(record)
fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter the product ID:131
# Enter the product Name:Milk biscuits
# Enter the product Price:20
# Enter the quantity :30
# Enter the discount:0
# Enter the Category the product belongs to:Food

# %%
record
# Out:
# {'101': {'Name': 'Chocolate pudding',
#   'price': 100,
#   'quantity': 30,
#   'discount': 5,
#   'Category': 'Food'},
#  '102': {'Name': 'Chocolate Cake',
#   'pr': 800,
#   'quantity': 100,
#   'discount': 12,
#   'Category': 'Food'},
#  '103': {'Name': 'Drinks',
#   'price': 85,
#   'quantity': 100,
#   'discount': 10,
#   'Category': 'Food'},
#  '104': {'Name': 'Candy',
#   'price': 5,
#   'quantity': 500,
#   'discount': 2,
#   'Category': 'Food'},
#  '105': {'Name': 'Butter',
#   'price': 20,
#   'quantity': 50,
#   'discount': 5,
#   'Category': 'Food'},
#  '106': {'Name': 'Biscuit',
#   'price': 50,
#   'quantity': 100,
#   'discount': 5,
#   'Category': 'Food'},
#  '107': {'Name': 'Cookies',
#   'price': 15,
#   'quantity': 0,
#   'discount': 5,
#   'Category': 'Food'},
#  '108': {'Name': 'Milk',
#   'price': 30,
#   'quantity': 20,
#   'discount': 2,
#   'Category': 'Food'},
#  '109': {'Name': 'Headphones',
#   'price': 1999,
#   'quantity': 10,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '110': {'Name': 'Speaker',
#   'price': 999,
#   'quantity': 10,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '111': {'Name': 'Stabilizer',
#   'price': 599,
#   'quantity': 15,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '112': {'Name': 'Mixer',
#   'price': 799,
#   'quantity': 10,
#   'discount': 15,
#   'Category': 'Hardware'},
#  '113': {'Name': 'Charger',
#   'price': 199,
#   'quantity': 45,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '114': {'Name': 'DVD',
#   'price': 1900,
#   'quantity': 10,
#   'discount': 20,
#   'Category': 'Hardware'},
#  '115': {'Name': 'Camera',
#   'price': 999,
#   'quantity': 50,
#   'discount': 0,
#   'Category': 'Hardware'},
#  '116': {'Name': 'Chips',
#   'price': 10,
#   'quantity': 30,
#   'discount': 0,
#   'Category': 'Food'},
#  '117': {'Name': 'Milk Cake',
#   'pr': 80,
#   'quantity': 100,
#   'discount': 5,
#   'Category': 'Food'},
#  '118': {'Name': 'Diet coke',
#   'price': 85,
#   'quantity': 100,
#   'discount': 10,
#   'Category': 'Food'},
#  '119': {'Name': 'Remote',
#   'price': 199,
#   'quantity': 10,
#   'discount': 5,
#   'Category': 'Hardware'},
#  '120': {'Name': 'Coke',
#   'price': 50,
#   'quantity': 500,
#   'discount': 5,
#   'Category': 'Food'},
#  '121': {'Name': 'Noodles',
#   'price': 20,
#   'quantity': 50,
#   'discount': 0,
#   'Category': 'Food'},
#  '122': {'Name': 'Ketchep',
#   'price': 50,
#   'quantity': 100,
#   'discount': 5,
#   'Category': 'Food'},
#  '123': {'Name': 'Batter',
#   'price': 35,
#   'quantity': 40,
#   'discount': 0,
#   'Category': 'Food'},
#  '124': {'Name': 'Paneer',
#   'price': 30,
#   'quantity': 20,
#   'discount': 0,
#   'Category': 'Food'},
#  '125': {'Name': 'iphone5',
#   'price': 50000,
#   'quantity': 5,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '126': {'Name': 'Connector',
#   'price': 299,
#   'quantity': 10,
#   'discount': 5,
#   'Category': 'Hardware'},
#  '127': {'Name': 'Pendrive',
#   'price': 199,
#   'quantity': 18,
#   'discount': 5,
#   'Category': 'Hardware'},
#  '128': {'Name': 'Flashlight',
#   'price': 400,
#   'quantity': 40,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '129': {'Name': 'Harddrive',
#   'price': 599,
#   'quantity': 10,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '130': {'Name': 'Modem',
#   'price': 699,
#   'quantity': 10,
#   'discount': 5,
#   'Category': 'Hardware'},
#  '131': {'Name': 'Milk biscuits',
#   'price': 20,
#   'quantity': 30,
#   'discount': 0,
#   'Category': 'Food'}}

# %%
del record['111']

# %%
record
# Out:
# {'101': {'Name': 'Chocolate pudding',
#   'price': 100,
#   'quantity': 30,
#   'discount': 5,
#   'Category': 'Food'},
#  '102': {'Name': 'Chocolate Cake',
#   'pr': 800,
#   'quantity': 100,
#   'discount': 12,
#   'Category': 'Food'},
#  '103': {'Name': 'Drinks',
#   'price': 85,
#   'quantity': 100,
#   'discount': 10,
#   'Category': 'Food'},
#  '104': {'Name': 'Candy',
#   'price': 5,
#   'quantity': 500,
#   'discount': 2,
#   'Category': 'Food'},
#  '105': {'Name': 'Butter',
#   'price': 20,
#   'quantity': 50,
#   'discount': 5,
#   'Category': 'Food'},
#  '106': {'Name': 'Biscuit',
#   'price': 50,
#   'quantity': 100,
#   'discount': 5,
#   'Category': 'Food'},
#  '107': {'Name': 'Cookies',
#   'price': 15,
#   'quantity': 0,
#   'discount': 5,
#   'Category': 'Food'},
#  '108': {'Name': 'Milk',
#   'price': 30,
#   'quantity': 20,
#   'discount': 2,
#   'Category': 'Food'},
#  '109': {'Name': 'Headphones',
#   'price': 1999,
#   'quantity': 10,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '110': {'Name': 'Speaker',
#   'price': 999,
#   'quantity': 10,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '112': {'Name': 'Mixer',
#   'price': 799,
#   'quantity': 10,
#   'discount': 15,
#   'Category': 'Hardware'},
#  '113': {'Name': 'Charger',
#   'price': 199,
#   'quantity': 45,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '114': {'Name': 'DVD',
#   'price': 1900,
#   'quantity': 10,
#   'discount': 20,
#   'Category': 'Hardware'},
#  '115': {'Name': 'Camera',
#   'price': 999,
#   'quantity': 50,
#   'discount': 0,
#   'Category': 'Hardware'},
#  '116': {'Name': 'Chips',
#   'price': 10,
#   'quantity': 30,
#   'discount': 0,
#   'Category': 'Food'},
#  '117': {'Name': 'Milk Cake',
#   'pr': 80,
#   'quantity': 100,
#   'discount': 5,
#   'Category': 'Food'},
#  '118': {'Name': 'Diet coke',
#   'price': 85,
#   'quantity': 100,
#   'discount': 10,
#   'Category': 'Food'},
#  '119': {'Name': 'Remote',
#   'price': 199,
#   'quantity': 10,
#   'discount': 5,
#   'Category': 'Hardware'},
#  '120': {'Name': 'Coke',
#   'price': 50,
#   'quantity': 500,
#   'discount': 5,
#   'Category': 'Food'},
#  '121': {'Name': 'Noodles',
#   'price': 20,
#   'quantity': 50,
#   'discount': 0,
#   'Category': 'Food'},
#  '122': {'Name': 'Ketchep',
#   'price': 50,
#   'quantity': 100,
#   'discount': 5,
#   'Category': 'Food'},
#  '123': {'Name': 'Batter',
#   'price': 35,
#   'quantity': 40,
#   'discount': 0,
#   'Category': 'Food'},
#  '124': {'Name': 'Paneer',
#   'price': 30,
#   'quantity': 20,
#   'discount': 0,
#   'Category': 'Food'},
#  '125': {'Name': 'iphone5',
#   'price': 50000,
#   'quantity': 5,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '126': {'Name': 'Connector',
#   'price': 299,
#   'quantity': 10,
#   'discount': 5,
#   'Category': 'Hardware'},
#  '127': {'Name': 'Pendrive',
#   'price': 199,
#   'quantity': 18,
#   'discount': 5,
#   'Category': 'Hardware'},
#  '128': {'Name': 'Flashlight',
#   'price': 400,
#   'quantity': 40,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '129': {'Name': 'Harddrive',
#   'price': 599,
#   'quantity': 10,
#   'discount': 10,
#   'Category': 'Hardware'},
#  '130': {'Name': 'Modem',
#   'price': 699,
#   'quantity': 10,
#   'discount': 5,
#   'Category': 'Hardware'},
#  '131': {'Name': 'Milk biscuits',
#   'price': 20,
#   'quantity': 30,
#   'discount': 0,
#   'Category': 'Food'}}
