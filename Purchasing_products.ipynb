# %%
records={"101": {"Name": "Chocolate pudding", "price": 100, "quantity": 30,"discount": 5 , "Category":"Food"}, 
 "102": {"Name": "Chocolate Cake", "pr": 800, "quantity": 100,"discount": 12 , "Category":"Food"}, 
 "103": {"Name": "Drinks", "price": 85, "quantity": 100 , "discount":10 , "Category":"Food"}, 
 "104": {"Name": "Candy", "price": 5, "quantity": 500 , "discount":2 , "Category":"Food"}, 
 "105": {"Name": "Butter", "price": 20, "quantity": 50 , "discount":5 , "Category":"Food"}, 
 "106": {"Name": "Biscuit", "price": 50, "quantity": 100 , "discount":5 , "Category":"Food"},
 "107": {"Name": "Cookies", "price": 15, "quantity": 0 , "discount":5 , "Category":"Food"},
 "108": {"Name": "Milk", "price": 30, "quantity": 20 , "discount":2 , "Category":"Food"},
 "109": {"Name": "Headphones", "price": 1999, "quantity": 10 , "discount":10 , "Category":"Hardware"},
 "110": {"Name": "Speaker", "price": 999, "quantity": 10 , "discount":10 , "Category":"Hardware"},     
 "111": {"Name": "Stabilizer", "price": 599, "quantity": 15 , "discount":10 , "Category":"Hardware"},
 "112": {"Name": "Mixer", "price": 799, "quantity": 10 , "discount":15 , "Category":"Hardware"},
 "113": {"Name": "Charger", "price": 199, "quantity": 45 , "discount":10 , "Category":"Hardware"},
 "114": {"Name": "DVD", "price": 1900, "quantity": 10 , "discount":20 , "Category":"Hardware"},
 "115": {"Name": "Camera", "price": 999, "quantity": 50 , "discount":0 , "Category":"Hardware"},
 "116": {"Name": "Chips", "price": 10, "quantity": 30,"discount": 0 , "Category":"Food"}, 
 "117": {"Name": "Milk Cake", "pr": 80, "quantity": 100,"discount": 5 , "Category":"Food"}, 
 "118": {"Name": "Diet coke", "price": 85, "quantity": 100 , "discount":10 , "Category":"Food"}, 
 "119": {"Name": "Remote", "price": 199, "quantity": 10 , "discount":5 , "Category":"Hardware"},
 "120": {"Name": "Coke", "price": 50, "quantity": 500 , "discount":5 , "Category":"Food"}, 
 "121": {"Name": "Noodles", "price": 20, "quantity": 50 , "discount":0 , "Category":"Food"}, 
 "122": {"Name": "Ketchep", "price": 50, "quantity": 100 , "discount":5 , "Category":"Food"},
 "123": {"Name": "Batter", "price": 35, "quantity": 40 , "discount":0 , "Category":"Food"},
 "124": {"Name": "Paneer", "price": 30, "quantity": 20 , "discount":0 , "Category":"Food"},
 "125": {"Name": "iphone5", "price": 50000, "quantity": 5 , "discount":10 , "Category":"Hardware"},
 "126": {"Name": "Connector", "price": 299, "quantity": 10 , "discount":5 , "Category":"Hardware"},
 "127": {"Name": "Pendrive", "price": 199, "quantity": 18 , "discount":5 , "Category":"Hardware"},
 "128": {"Name": "Flashlight", "price": 400, "quantity": 40 , "discount":10 , "Category":"Hardware"},
 "129": {"Name": "Harddrive", "price": 599, "quantity": 10 , "discount":10 , "Category":"Hardware"},
 "130": {"Name": "Modem", "price": 699, "quantity": 10 , "discount":5 , "Category":"Hardware"}}

# %%
records
# Out:
# {'101': {'Name': 'Chocolate pudding',
#   'price': 100,
#   'quantity': 30,
#   'discount': 5,
#   'Category': 'Food'},
#  '102': {'Name': 'Chocolate Cake',
#   'pr': 800,
#   'quantity': 100,
#   'discount': 12,
#   'Category': 'Food'},
#  '103': {'Name': 'Drinks',
#   'price': 85,
#   'quantity': 100,
#   'discount': 10,
#   'Category': 'Food'},
#  '104': {'Name': 'Candy',
#   'price': 5,
#   'quantity': 500,
#   'discount': 2,
#   'Category': 'Food'},
#  '105': {'Name': 'Butter',
#   'price': 20,
#   'quantity': 50,
#   'discount': 5,
#   'Category': 'Food'},
#  '106': {'Name': 'Biscuit',
#   'price': 50,
#   'quantity': 100,
#   'discount': 5,
#   'Category': 'Food'},
#  '107': {'Name': 'Cookies',
#   'price': 15,
#   'quantity': 0,
#   'discount': 5,
#   'Category': 'Food'},
#  '108': {'Name': 'Milk',
#   'price': 30,
#   'quantity': 20,
#   'discount': 2,
#   'Category': 'Food'},
#  '109': {'Name': 'Headphones',
#   'price': 1999,
#   'quantity': 10,
#   'discount': 10,
# ...

# %%
ui_prod  = str(input("Enter the product_ID: "))
ui_quant = int(input("Enter the quantity: "))
print("Product: ", records[ui_prod]['Name'])
print("Price: ", records[ui_prod]['price'])
print("Billing Amount: ", records[ui_prod]['price'] * ui_quant)

records[ui_prod]['quantity'] = records[ui_prod]['quantity'] - ui_quant
# Out:
# Enter the product_ID: 101
# Enter the quantity: 5
# Product:  Chocolate pudding
# Price:  100
# Billing Amount:  500

# %%
import json
js = json.dumps(records)
fd = open("record.json",'w')
fd.write(js)
fd.close()

# %%
sales = {1 : {'prod' : 'Chips', 'quantity' : 5, "price" : 10, "GST" : 2},
         2 : {'prod' : 'Chocolate pudding', 'quantity' : 10, "price" : 100, "GST" : 2},
         3 : {'prod' : 'Drinks', 'quantity' : 8, "price" : 85, "GST" : 5},
         4 : {'prod' : 'Coke', 'quantity' : 5, "price" : 50, "GST" : 2},
         5 : {'prod' : 'Charger', 'quantity' : 6, "price" : 199, "GST" : 2}, 
         6 : {'prod' : 'Butter', 'quantity' : 15, "price" : 20, "GST" : 5},
         7 : {'prod' : 'Milk', 'quantity' : 15, "price" : 30, "GST" : 5},
         8 : {'prod' : 'Paneer', 'quantity' : 5, "price" : 30, "GST" : 2}}

# %%
sales = {1 : {'prod' : ui_prod, 'quantity' : ui_quant, 'amount': records[ui_prod]['price'] * ui_quant},
         2 : {'prod' : ui_prod, 'quantity' : ui_quant, 'amount': records[ui_prod]['price'] * ui_quant},
         3 : {'prod' : ui_prod, 'quantity' : ui_quant, 'amount': records[ui_prod]['price'] * ui_quant},
         4 : {'prod' : ui_prod, 'quantity' : ui_quant, 'amount': records[ui_prod]['price'] * ui_quant},
         5 : {'prod' : ui_prod, 'quantity' : ui_quant, 'amount': records[ui_prod]['price'] * ui_quant},
         6 : {'prod' : ui_prod, 'quantity' : ui_quant, 'amount': records[ui_prod]['price'] * ui_quant},
         7 : {'prod' : ui_prod, 'quantity' : ui_quant, 'amount': records[ui_prod]['price'] * ui_quant},
         8 : {'prod' : ui_prod, 'quantity' : ui_quant, 'amount': records[ui_prod]['price'] * ui_quant}}

# %%
sale = json.dumps(sales)

# %%
sale
# Out:
# '{"1": {"prod": "101", "quantity": 5, "amount": 500}, "2": {"prod": "101", "quantity": 5, "amount": 500}, "3": {"prod": "101", "quantity": 5, "amount": 500}, "4": {"prod": "101", "quantity": 5, "amount": 500}, "5": {"prod": "101", "quantity": 5, "amount": 500}, "6": {"prod": "101", "quantity": 5, "amount": 500}, "7": {"prod": "101", "quantity": 5, "amount": 500}, "8": {"prod": "101", "quantity": 5, "amount": 500}}'

# %%
js = json.dumps(sale)

# %%
js
# Out:
# '"{\\"1\\": {\\"prod\\": \\"101\\", \\"quantity\\": 5, \\"amount\\": 500}, \\"2\\": {\\"prod\\": \\"101\\", \\"quantity\\": 5, \\"amount\\": 500}, \\"3\\": {\\"prod\\": \\"101\\", \\"quantity\\": 5, \\"amount\\": 500}, \\"4\\": {\\"prod\\": \\"101\\", \\"quantity\\": 5, \\"amount\\": 500}, \\"5\\": {\\"prod\\": \\"101\\", \\"quantity\\": 5, \\"amount\\": 500}, \\"6\\": {\\"prod\\": \\"101\\", \\"quantity\\": 5, \\"amount\\": 500}, \\"7\\": {\\"prod\\": \\"101\\", \\"quantity\\": 5, \\"amount\\": 500}, \\"8\\": {\\"prod\\": \\"101\\", \\"quantity\\": 5, \\"amount\\": 500}}"'

# %%
ui_prod  = str(input("Enter the product_Id: "))
ui_quant = int(input("Enter the quantity: "))
print("Product: ", records[ui_prod]['Name'])
print("price: ", records[ui_prod]['price'])
print("Total Amount: ", records[ui_prod]['price'] * ui_quant)
print("Quantity Before:",records[ui_prod]['quantity'])
records[ui_prod]['quantity'] = records[ui_prod]['quantity'] - ui_quant
print("Quantity of the product remaining:",records[ui_prod]['quantity'])
print(records)
# Out:
# Enter the product_Id: 106
# Enter the quantity: 10
# Product:  Biscuit
# price:  50
# Total Amount:  500
# Quantity Before: 96
# Quantity of the product remaining: 86
# ...

# %%
ui_prod  = str(input("Enter the product_Id: "))
ui_quant = int(input("Enter the quantity: "))
print("Product: ", records[ui_prod]['Name'])
print("price: ", records[ui_prod]['price'])
print("Total Amount: ", records[ui_prod]['price'] * ui_quant)
print("Quantity Before:",records[ui_prod]['quantity'])
records[ui_prod]['quantity'] = records[ui_prod]['quantity'] - ui_quant
print("Quantity of the product remaining:",records[ui_prod]['quantity'])
# Out:
# Enter the product_Id: 110
# Enter the quantity: 3
# Product:  Speaker
# price:  999
# Total Amount:  2997
# Quantity Before: 10
# Quantity of the product remaining: 7

# %%
records
# Out:
# {'101': {'Name': 'Chocolate pudding',
#   'price': 100,
#   'quantity': 28,
#   'discount': 5,
#   'Category': 'Food'},
#  '102': {'Name': 'Chocolate Cake',
#   'pr': 800,
#   'quantity': 100,
#   'discount': 12,
#   'Category': 'Food'},
#  '103': {'Name': 'Drinks',
#   'price': 85,
#   'quantity': 96,
#   'discount': 10,
#   'Category': 'Food'},
#  '104': {'Name': 'Candy',
#   'price': 5,
#   'quantity': 500,
#   'discount': 2,
#   'Category': 'Food'},
#  '105': {'Name': 'Butter',
#   'price': 20,
#   'quantity': 47,
#   'discount': 5,
#   'Category': 'Food'},
#  '106': {'Name': 'Biscuit',
#   'price': 50,
#   'quantity': 86,
#   'discount': 5,
#   'Category': 'Food'},
#  '107': {'Name': 'Cookies',
#   'price': 15,
#   'quantity': 0,
#   'discount': 5,
#   'Category': 'Food'},
#  '108': {'Name': 'Milk',
#   'price': 30,
#   'quantity': 15,
#   'discount': 2,
#   'Category': 'Food'},
#  '109': {'Name': 'Headphones',
#   'price': 1999,
#   'quantity': 10,
#   'discount': 10,
# ...
